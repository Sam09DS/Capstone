# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
health_data=pd.read_csv('health care diabetes.csv')

# %%
health_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ## 1. Perform descriptive analysis. Understand the variables and their corresponding values. On the columns below, a value of zero does not make sense and thus indicates missing value:
#
# • Glucose
#
# • BloodPressure
#
# • SkinThickness
#
# • Insulin
#
# • BMI

# %%
health_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
health_data.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
health_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
Positive = health_data[health_data['Outcome']==1]
Positive.head(10)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 2             8      183             64              0        0  23.3
# 4             0      137             40             35      168  43.1
# 6             3       78             50             32       88  31.0
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 11           10      168             74              0        0  38.0
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
# 15            7      100              0              0        0  30.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# 2                      0.672   32        1
# 4                      2.288   33        1
# ...

# %% [markdown]
# # Insights from Descriptive Analysis
#
# ### There is 768 observations of 9 variable. Independent variables are Pregnencies , Glucose, BloodPressure, Insulin, BMI and DiabetesPedigree Function. Age is Outcome Variable. Average Age of Patients are 33.24 with minimum being 21 and maximum 81. Avg. value of independent variables are Preg = 3.845052,Glucose = 120.894531, BP = 69.105469, ST=20.536458, Insulin = 79.799479, BMI = 31.992578 DPF = 0.471876 . Variation in variables can be easily observed from table below :->

# %%
health_data['Glucose'].value_counts().head(20)
# Out:
# 100    17
# 99     17
# 129    14
# 125    14
# 111    14
# 106    14
# 95     13
# 108    13
# 105    13
# 102    13
# 112    13
# 122    12
# 109    12
# 107    11
# 117    11
# 90     11
# 120    11
# 114    11
# 124    11
# 128    11
# Name: Glucose, dtype: int64

# %%
print("Standerd Deviation of each variables are ==>")
health_data.apply(np.std)
# Out:
# Standerd Deviation of each variables are ==>
# Pregnancies                   3.367384
# Glucose                      31.951796
# BloodPressure                19.343202
# SkinThickness                15.941829
# Insulin                     115.168949
# BMI                           7.879026
# DiabetesPedigreeFunction      0.331113
# Age                          11.752573
# Outcome                       0.476641
# dtype: float64

# %%
plt.figure(figsize=(6,4),dpi=100)
plt.xlabel("Glucose Class")
health_data["Glucose"].plot.hist()
sns.set_style(style="darkgrid")
print("Mean of Glucose level is :-", health_data['Glucose'].mean())
print("Datatype of Glucose Variable is:",health_data['Glucose'].dtypes)
# Out:
# Mean of Glucose level is :- 120.89453125
# Datatype of Glucose Variable is: int64

# %%
health_data['Glucose']=health_data['Glucose'].replace(0,health_data['Glucose'].mean())

# %%
plt.figure(figsize=(6,4),dpi=100)
plt.xlabel("Glucose Class")
health_data["Glucose"].plot.hist()
sns.set_style(style="darkgrid")
print("Mean of Glucose level is :-", health_data['Glucose'].mean())
print("Datatype of Glucose Variable is:",health_data['Glucose'].dtypes)
# Out:
# Mean of Glucose level is :- 121.68160502115886
# Datatype of Glucose Variable is: float64

# %%
health_data['BloodPressure']=health_data['BloodPressure'].replace(0,health_data['BloodPressure'].mean())

# %%
plt.figure(figsize=(6,4),dpi=100)
plt.xlabel("BloodPressure Class")
health_data["BloodPressure"].plot.hist()
sns.set_style(style="darkgrid")
print("Mean of Glucose level is :-", health_data['BloodPressure'].mean())
print("Datatype of Glucose Variable is:",health_data['BloodPressure'].dtypes)
# Out:
# Mean of Glucose level is :- 72.25480651855469
# Datatype of Glucose Variable is: float64

# %%
health_data['SkinThickness']=health_data['SkinThickness'].replace(0,health_data['SkinThickness'].mean())

# %%
plt.figure(figsize=(6,4),dpi=100)
plt.xlabel("SkinThickness Class")
health_data["SkinThickness"].plot.hist()
sns.set_style(style="darkgrid")
print("Mean of SkinThickness level is :-", health_data["SkinThickness"].mean())
print("Datatypes of SkinThickness Variable is :-",health_data["SkinThickness"].dtypes)
# Out:
# Mean of SkinThickness level is :- 26.606479220920118
# Datatypes of SkinThickness Variable is :- float64

# %%
health_data["Insulin"]=health_data["Insulin"].replace(0,health_data["Insulin"].mean())

# %%
plt.figure(figsize=(6,4),dpi=100)
plt.xlabel("Insulin")
health_data["Insulin"].plot.hist()
sns.set_style(style="darkgrid")
print("Mean of Insulin level is :-", health_data['Insulin'].mean())
print("Datatype of Insulin Variable is:",health_data['Insulin'].dtypes)
# Out:
# Mean of Insulin level is :- 118.66016303168442
# Datatype of Insulin Variable is: float64

# %%
health_data["BMI"]=health_data["BMI"].replace(0,health_data["BMI"].mean())

# %%
plt.figure(figsize=(6,4),dpi=100)
plt.xlabel("BMI Class")
health_data["BMI"].plot.hist()
sns.set_style(style="darkgrid")
print("Mean of BMI level is :-", health_data['BMI'].mean())
print("Datatype of Glucose Variable is:",health_data['BMI'].dtypes)
# Out:
# Mean of BMI level is :- 32.45080515543617
# Datatype of Glucose Variable is: float64

# %%
plt.figure(figsize=(5,3),dpi=100)
plt.title('Checking Misssing Value with Haeatmap')
sns.heatmap(health_data.isnull(),cmap='magma',yticklabels=False)

# %%
health_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6    148.0           72.0      35.000000   79.799479  33.6
# 1            1     85.0           66.0      29.000000   79.799479  26.6
# 2            8    183.0           64.0      20.536458   79.799479  23.3
# 3            1     89.0           66.0      23.000000   94.000000  28.1
# 4            0    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
health_data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
## df.to_csv('after_week1.csv',index=False)

# %% [markdown]
# # WEEK 2

# %% [markdown]
# # Project Task: Week 2
# ## Data Exploration:
#
# ### 1. Check the balance of the data by plotting the count of outcomes by their value. Describe your findings and plan future course of action.
#
# ### 2. Create scatter charts between the pair of variables to understand the relationships. Describe your findings.
#
# ### 3. Perform correlation analysis. Visually explore it using a heat map.

# %%
##1.1 plt.hist(Positive['BMI'],histtype='stepfilled',bins=20)
##1.2 Positive['BMI'].value_counts().head(7)

##2.1 plt.hist(Positive['Glucose'],histtype='stepfilled',bins=20)
##2.2 Positive['Glucose'].value_counts().head(7)

##3.1 plt.hist(Positive['BloodPressure'],histtype='stepfilled',bins=20)
##3.2 Positive['BloodPressure'].value_counts().head(7)

##4.1 plt.hist(Positive['SkinThickness'],histtype='stepfilled',bins=20)
##4.2 Positive['SkinThickness'].value_counts().head(7)

##5.1 plt.hist(Positive['Insulin'],histtype='stepfilled',bins=20)
##5.2 Positive['Insulin'].value_counts().head(7)

## We can use all these individual code and individually check all the counts

# %% [markdown]
# ### Countplot

# %%
sns.set_style('darkgrid')
sns.countplot(health_data['Outcome'])
plt.title('Countplot of Outcome')
plt.xlabel('Outcome')
plt.ylabel('Count')
print('Count of class is:\n',health_data['Outcome'].value_counts())
# Out:
# Count of class is:
#  0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# ###### We can see that both class is balanced so we need not to perform any sampling method to maintain the balance between both classes. Therefor i will be directly using this data in training and testing purpose without performing any sampling method. Meanwhile during Model Validation , we also need not worry abour ROC Curve because data is not imbalanced, but as this is a medical data so i will be using ROC curve to make sure TYPE 2 ERROR will not be there.

# %%
sns.pairplot(health_data)
plt.title('Scatter Plot between variables')
# Out:
# Text(0.5, 1.0, 'Scatter Plot between variables')

# %%
health_data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.127964       0.208984       0.013376
# Glucose                      0.127964  1.000000       0.219666       0.160766
# BloodPressure                0.208984  0.219666       1.000000       0.134155
# SkinThickness                0.013376  0.160766       0.134155       1.000000
# Insulin                     -0.018082  0.396597       0.010926       0.240361
# BMI                          0.021546  0.231478       0.281231       0.535703
# DiabetesPedigreeFunction    -0.033523  0.137106       0.000371       0.154961
# Age                          0.544341  0.266600       0.326740       0.026423
# Outcome                      0.221898  0.492908       0.162986       0.175026
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018082  0.021546                 -0.033523
# ...

# %%
sns.heatmap(health_data.corr())

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(health_data.corr(),annot=True,cmap='viridis')

# %% [markdown]
# ### We can see from scatter plot that there is no strong multicolinearity among features, but between skinthickness and BMI,Pregnancies and age it looks like there is small  positive correlation.After exploring and ploting heatmap for correlation.We can clearly see that Glucose and BMI has some impact on outcome. There is a slight positive correlation between BMI and Skinthickness or Pregnancies and age

# %% [markdown]
# ## Project Task: Week 3
# ### Data Modeling:
#
# #### 1. Devise strategies for model building. It is important to decide the right validation framework. Express your thought process.

# %%
health_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6    148.0           72.0      35.000000   79.799479  33.6
# 1            1     85.0           66.0      29.000000   79.799479  26.6
# 2            8    183.0           64.0      20.536458   79.799479  23.3
# 3            1     89.0           66.0      23.000000   94.000000  28.1
# 4            0    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
features = health_data.iloc[:,[0,1,2,3,4,5,6,7]].values
label = health_data.iloc[:, 8].values

# %%
#x=df.iloc[:,:-1].values
#y=df.iloc[:,-1].values
#Python list slicing syntax states that for a:b it will get a and everything upto but not including b. a: will get a and 
#everything after it. :b will get everything before b but not b. The list index of -1 refers to the last element. :-1 adheres
#to the same standards as above in that this gets everything before the last element but not the last element.
#If you want the last element included use :.

# %%
#Train test split
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(features,
                                                label,
                                                test_size = 0.2,
                                                random_state = 10)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scale = StandardScaler()
X_train_std=Scale.fit_transform(X_train)
X_test_std=Scale.transform(X_test)

# %%
norm = lambda a:(a-min(a))/(max(a)-min(a))

# %%
health_data_norm=health_data.iloc[:,:-1]

# %%
df_normalized=health_data_norm.apply(norm)

# %%
x_train_norm, x_test_norm, y_train_norm, y_test_norm = train_test_split(df_normalized.values, label, test_size = 0.20,random_state=10)

# %%
#Feature Scaling is a technique to standardize the independent features present in the data in a fixed range. 
#It is performed during the data pre-processing to handle highly varying magnitudes or values or units. 
#So, we use Feature Scaling to bring all values to same magnitudes and thus, tackle this issue

# %%
print(x_train_norm.shape)
print(x_test_norm.shape)
print(y_train_norm.shape)
print(y_test_norm.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %% [markdown]
# ##### Data is mostly numerical and in such scenario , Logistic Regression works fine. We have also seen in week 2 that variables aredepending on target somewhat linearly, So this is also good for Logistic Regression. I will be also using Support Vector Classifier, Perceptron Learning, Random Forest (Ensemble Learning) to see if i can improve accuracy. Note these learning algorithm also works on linear data very well. To validate model i will be using train test split, for accuracy i will be using accuracy using confusion matrix because classes are balanced and i will be also considering. ROC Curve and ROC AUC Score to make sure Type 2 Error will not occur for Positive class, that is 1

# %% [markdown]
#  ## KNN
# #### KNN With Standard Scaling

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors =25)
knn_model.fit(X_train_std, Y_train)
knn_pred=knn_model.predict(X_test_std)

# %%
from sklearn import metrics

# %%
print("Model Validation ==>\n")
print("Accuracy Score of KNN Model::")
print(metrics.accuracy_score(Y_test,knn_pred))
print("\n","Classification Report::")
print(metrics.classification_report(Y_test,knn_pred),'\n')
print("\n","ROC Curve")
knn_prob=knn_model.predict_proba(X_test_std)
knn_prob1=knn_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(Y_test,knn_prob1)
roc_auc_knn=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_knn)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of KNN Model::
# 0.7012987012987013
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.70      0.92      0.79        95
#            1       0.72      0.36      0.48        59
#
#     accuracy                           0.70       154
#    macro avg       0.71      0.64      0.63       154
# weighted avg       0.71      0.70      0.67       154
#
#
#
#  ROC Curve

# %% [markdown]
# #### KNN With Normalization

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model_norm = KNeighborsClassifier(n_neighbors=25)
#Using 25 Neighbors just as thumb rule sqrt of observation
knn_model_norm.fit(x_train_norm, y_train_norm)
knn_pred_norm = knn_model_norm.predict(x_test_norm)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of KNN Model with Normalization::")
print(metrics.accuracy_score(y_test_norm,knn_pred_norm))
print("\n","Classification Report::")
print(metrics.classification_report(y_test_norm,knn_pred_norm),'\n')
print("\n","ROC Curve")
print(metrics.classification_report(y_test_norm,knn_pred_norm),'\n')
print("\n","ROC Curve")
knn_prob_norm=knn_model.predict_proba(x_test_norm)
knn_prob_norm1=knn_prob_norm[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test_norm,knn_prob_norm1)
roc_auc_knn=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_knn)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of KNN Model with Normalization::
# 0.7077922077922078
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.71      0.88      0.79        95
#            1       0.69      0.42      0.53        59
#
#     accuracy                           0.71       154
#    macro avg       0.70      0.65      0.66       154
# weighted avg       0.71      0.71      0.69       154
#
#
#
#  ROC Curve
#               precision    recall  f1-score   support
#
#            0       0.71      0.88      0.79        95
#            1       0.69      0.42      0.53        59
#
#     accuracy                           0.71       154
#    macro avg       0.70      0.65      0.66       154
# weighted avg       0.71      0.71      0.69       154
#
#
#
#  ROC Curve

# %% [markdown]
# ###### We can clearly see that KNN with Standardization is better than Normalization, So later i will build models using Z Score Standardization and will compare with KNN
#
# ## Support Vectore Classifier

# %%
from sklearn.svm import SVC
svc_model_linear = SVC(kernel='linear',random_state=0,probability=True,C=0.01) 
svc_model_linear.fit(X_train_std,Y_train)
svc_pred=svc_model_linear.predict(X_test_std)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of SVC Model with Linear Kernel::")
print(metrics.accuracy_score(Y_test,svc_pred))
print("\n","Classification Report::")
print(metrics.classification_report(Y_test,svc_pred),'\n')
print("\n","ROC Curve")
svc_prob_linear=svc_model_linear.predict_proba(X_test_std)
svc_prob_linear1=svc_prob_linear[:,1]
fpr,tpr,thresh=metrics.roc_curve(Y_test,svc_prob_linear1)
roc_auc_svc=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_svc)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of SVC Model with Linear Kernel::
# 0.7402597402597403
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.72      0.94      0.82        95
#            1       0.81      0.42      0.56        59
#
#     accuracy                           0.74       154
#    macro avg       0.77      0.68      0.69       154
# weighted avg       0.76      0.74      0.72       154
#
#
#
#  ROC Curve

# %% [markdown]
# #### LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression()
lr_model.fit(X_train_std,Y_train)
lr_pred = lr_model.predict(X_test_std)

# %%
print('Model Validation ==>\n')
print('Accuracy Score of Logistic Regression Model::')
print(metrics.accuracy_score(Y_test,lr_pred))
print('\n','Classification Report::')
print(metrics.classification_report(Y_test,lr_pred),'\n')
print('\n','ROC Curve')
lr_prob=lr_model.predict_proba(X_test_std)
lr_prob1=lr_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(Y_test,lr_prob1)
roc_auc_lr=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_lr)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of Logistic Regression Model::
# 0.7337662337662337
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.74      0.88      0.80        95
#            1       0.72      0.49      0.59        59
#
#     accuracy                           0.73       154
#    macro avg       0.73      0.69      0.69       154
# weighted avg       0.73      0.73      0.72       154
#
#
#
#  ROC Curve

# %% [markdown]
# ## Ensemble Learning(RF)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=1000,random_state=10)
rf_model.fit(X_train_std,Y_train)
rf_pred = rf_model.predict(X_test_std)

# %%
print('Model Validation ==>\n')
print('Accuracy Score of Logistic Regression Model::')
print(metrics.accuracy_score(Y_test,rf_pred))
print('\n','Classification Report::')
print(metrics.classification_report(Y_test,rf_pred),'\n')
print('\n','ROC Curve')
rf_prob=rf_model.predict_proba(X_test_std)
rf_prob1=rf_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(Y_test,rf_prob1)
roc_auc_rf=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_rf)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of Logistic Regression Model::
# 0.7402597402597403
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80        95
#            1       0.71      0.54      0.62        59
#
#     accuracy                           0.74       154
#    macro avg       0.73      0.70      0.71       154
# weighted avg       0.74      0.74      0.73       154
#
#
#
#  ROC Curve
